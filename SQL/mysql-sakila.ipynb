# %% [markdown]
# # MySQL Project
# ---
# ```bash
# Author: Witchakorn Wanasanwongkot
# ```
# ## Sakila database
#
# The Sakila database is a nicely normalised schema modelling a DVD rental store, featuring things like films, actors, film-actor relationships, and a central inventory table that connects films, stores, and rentals.
#
# <p align="center">
#     <img src="https://www.jooq.org/img/sakila.png" width="100%"/>
# </p>
#
# *Image source: https://www.jooq.org/img/sakila.png*

# %%
import pandas as pd
import sqlalchemy as db

# %%
# Specify the MySQL database configurations.
config = {
    'host': 'localhost',
    'port': 3306,
    'user': 'root',
    'password': 'root',
    'database': 'sakila'
}

db_user = config.get('user')
db_pwd = config.get('password')
db_host = config.get('host')
db_port = config.get('port')
db_name = config.get('database')

# Specify connection string
connection_str = f'mysql+pymysql://{db_user}:{db_pwd}@{db_host}:{db_port}/{db_name}'

# Connect to `sakila` database
engine = db.create_engine(connection_str)
conn = engine.connect()
print(conn)
# Out:
# <sqlalchemy.engine.base.Connection object at 0x000001CFA2166A90>

# %%
# Display the names of all tables in the `sakila` database.
query = """
    SELECT TABLE_NAME 
    FROM INFORMATION_SCHEMA.TABLES
    WHERE TABLE_TYPE = 'BASE TABLE' AND TABLE_SCHEMA='sakila' ;
"""

pd.read_sql(query, con=conn).T
# Out:
#                0        1         2     3        4         5     6   \
# TABLE_NAME  actor  address  category  city  country  customer  film
#
#                     7              8          9          10        11  \
# TABLE_NAME  film_actor  film_category  film_text  inventory  language
#
#                  12      13     14     15
# TABLE_NAME  payment  rental  staff  store

# %%
# Display the count of records in both the `actor` and `film` tables.
query = """
    SELECT
        (SELECT COUNT(*) FROM actor) AS actor,
        (SELECT COUNT(*) FROM film) AS film;
"""

pd.read_sql(query, con=conn)
# Out:
#    actor  film
# 0    200  1000

# %%
# Display the actors whose names start with 'P' or 'A'.
query = """
    SELECT 
        * 
    FROM actor
    WHERE 
        first_name REGEXP '^[PA]';
"""

pd.read_sql(query, con=conn)
# Out:
#     actor_id first_name    last_name         last_update
# 0          1   PENELOPE      GUINESS 2006-02-15 04:34:33
# 1         29       ALEC        WAYNE 2006-02-15 04:34:33
# 2         34     AUDREY      OLIVIER 2006-02-15 04:34:33
# 3         46     PARKER     GOLDBERG 2006-02-15 04:34:33
# 4         49       ANNE       CRONYN 2006-02-15 04:34:33
# 5         54   PENELOPE      PINKETT 2006-02-15 04:34:33
# 6         65     ANGELA       HUDSON 2006-02-15 04:34:33
# 7         71       ADAM        GRANT 2006-02-15 04:34:33
# 8         76   ANGELINA      ASTAIRE 2006-02-15 04:34:33
# 9        104   PENELOPE       CRONYN 2006-02-15 04:34:33
# 10       120   PENELOPE       MONROE 2006-02-15 04:34:33
# 11       125     ALBERT        NOLTE 2006-02-15 04:34:33
# 12       132       ADAM       HOPPER 2006-02-15 04:34:33
# 13       144     ANGELA  WITHERSPOON 2006-02-15 04:34:33
# 14       146     ALBERT    JOHANSSON 2006-02-15 04:34:33
# 15       165         AL      GARLAND 2006-02-15 04:34:33
# 16       173       ALAN     DREYFUSS 2006-02-15 04:34:33
# 17       190     AUDREY       BAILEY 2006-02-15 04:34:33

# %%
# Display the top 10 actors who have acted in the most movies, ranked in descending order.
query = """
    SELECT
        first_name,
        last_name,
        COUNT(*) films
    FROM actor A
        JOIN film_actor B
            ON A.actor_id = B.actor_id
    GROUP BY 1, 2
    HAVING films >= 35
    ORDER BY 3 DESC;
"""

print("# It necessary to return more rows with values that match the last row in the limited result set")
pd.read_sql(query, con=conn)
# Out:
# # It necessary to return more rows with values that match the last row in the limited result set
#    first_name    last_name  films
# 0       SUSAN        DAVIS     54
# 1        GINA    DEGENERES     42
# 2      WALTER         TORN     41
# 3        MARY       KEITEL     40
# 4     MATTHEW       CARREY     39
# 5      SANDRA       KILMER     37
# 6    SCARLETT        DAMON     36
# 7         UMA         WOOD     35
# 8         VAL       BOLGER     35
# 9       HENRY        BERRY     35
# 10    GROUCHO        DUNST     35
# 11     ANGELA  WITHERSPOON     35
# 12     VIVIEN     BASINGER     35

# %%
# Display the number of films in each rating.
query = """
    SELECT
        rating,
        COUNT(*) n
    FROM film
    GROUP BY 1;
"""

pd.read_sql(query, con=conn)
# Out:
#   rating    n
# 0     PG  194
# 1      G  178
# 2  NC-17  210
# 3  PG-13  223
# 4      R  195

# %%
# Display the percentage of films in each rating.
query = """
    WITH num_rating AS (
    SELECT
        rating,
        COUNT(*) n,
        (SELECT COUNT(*) FROM film) AS totaln
    FROM film
    GROUP BY 1
    )

    SELECT
        rating,
        n,
        n / CAST(totaln AS REAL) AS percent
    FROM num_rating
    ORDER BY 2 DESC;
"""

pd.read_sql(query, con=conn)
# Out:
#   rating    n  percent
# 0  PG-13  223    0.223
# 1  NC-17  210    0.210
# 2      R  195    0.195
# 3     PG  194    0.194
# 4      G  178    0.178

# %%
# Generate a new email column using the firstname and lastname.
query = """
    SELECT
        first_name,
        last_name,
        CONCAT(LOWER(first_name), '.', LOWER(LEFT(last_name, 1)), '@sakila.com')  AS email
    FROM actor;
"""

pd.read_sql(query, con=conn)
# Out:
#     first_name     last_name                  email
# 0     PENELOPE       GUINESS  penelope.g@sakila.com
# 1         NICK      WAHLBERG      nick.w@sakila.com
# 2           ED         CHASE        ed.c@sakila.com
# 3     JENNIFER         DAVIS  jennifer.d@sakila.com
# 4       JOHNNY  LOLLOBRIGIDA    johnny.l@sakila.com
# ..         ...           ...                    ...
# 195       BELA        WALKEN      bela.w@sakila.com
# 196      REESE          WEST     reese.w@sakila.com
# 197       MARY        KEITEL      mary.k@sakila.com
# 198      JULIA       FAWCETT     julia.f@sakila.com
# 199      THORA        TEMPLE     thora.t@sakila.com
#
# [200 rows x 3 columns]

# %%
# Retrieve the customer data for those who live in Japan.
query = """
    SELECT
        A.customer_id,
        A.first_name,
        A.last_name,
        B.address,
        C.city,
        D.country
    FROM customer A
        JOIN address B 
            ON A.address_id = B.address_id
        JOIN city C 
            ON B.city_id = C.city_id
        JOIN country D 
            ON C.country_id = D.country_id
    WHERE D.country = 'Japan';
"""

pd.read_sql(query, con=conn)
# Out:
#     customer_id first_name  last_name                            address  \
# 0           574     JULIAN       VEST              923 Tangail Boulevard
# 1           141     DEBBIE      REYES                    928 Jaffna Loop
# 2           264  GWENDOLYN        MAY            446 Kirovo-Tepetsk Lane
# 3           194    KRISTEN     CHAVEZ               345 Oshawa Boulevard
# 4           299      JAMES     GANNON              1635 Kuwana Boulevard
# 5           519        RON     DELUCA                  1949 Sanya Street
# 6           240    MARLENE      WELCH            1148 Saarbrcken Parkway
# 7            54     TERESA     ROGERS  1964 Allappuzha (Alleppey) Street
# 8           396       EARL     SHANKS                  168 Cianjur Manor
# 9           391   CLARENCE      GAMEZ                767 Pyongyang Drive
# 10          163      CATHY    SPENCER           1287 Xi´angfan Boulevard
# 11           79     RACHEL     BARNES                       586 Tete Way
# 12          547       KURT     EMMONS                  1421 Quilmes Lane
# 13          401       TONY   CARRANZA                   454 Patiala Lane
# 14           34    REBECCA      SCOTT                     61 Tama Street
# 15          531      JAMIE      WAUGH                958 Sagamihara Lane
# 16          355      TERRY    GRISSOM                  619 Hunuco Avenue
# 17          253      TERRY    CARLSON                      752 Ondo Loop
# 18           53    HEATHER     MORRIS                 17 Kabul Boulevard
# 19          489    RICARDO     MEADOR            591 Sungai Petani Drive
# 20          365      BRUCE    SCHWARZ                 1565 Tangail Manor
# 21          404    STANLEY  SCROGGINS                1266 Laredo Parkway
# 22          337      JERRY     JORDON                  124 al-Manama Way
# 23          285     MIRIAM   MCKINNEY              1336 Benin City Drive
# 24           11       LISA   ANDERSON                1542 Tarlac Parkway
# 25            1       MARY      SMITH                     1913 Hanoi Way
# 26           29     ANGELA  HERNANDEZ                  786 Aurora Avenue
# 27          385    PHILLIP       HOLM                   102 Chapra Drive
# 28          429  FREDERICK     ISBELL                  1404 Taguig Drive
# 29          503      ANGEL    BARCLAY                   496 Celaya Drive
# 30          147     JOANNE  ROBERTSON               1337 Lincoln Parkway
#
#             city country
# 0       Akishima   Japan
# 1       Fukuyama   Japan
# 2   Higashiosaka   Japan
# 3           Hino   Japan
# 4      Hiroshima   Japan
# 5        Isesaki   Japan
# 6          Iwaki   Japan
# 7        Iwakuni   Japan
# 8       Iwatsuki   Japan
# 9      Izumisano   Japan
# 10  Kakamigahara   Japan
# 11      Kamakura   Japan
# 12      Kanazawa   Japan
# 13      Koriyama   Japan
# 14     Kurashiki   Japan
# 15        Kuwana   Japan
# 16        Matsue   Japan
# 17    Miyakonojo   Japan
# 18    Nagareyama   Japan
# 19       Okayama   Japan
# 20       Okinawa   Japan
# 21         Omiya   Japan
# 22      Onomichi   Japan
# 23          Otsu   Japan
# 24    Sagamihara   Japan
# 25        Sasebo   Japan
# 26   Shimonoseki   Japan
# 27          Tama   Japan
# 28       Tsuyama   Japan
# 29          Ueda   Japan
# 30         Urawa   Japan

# %%
# Show the list of comedy films with a 'PG' rating.
query = """
    SELECT
        C.name,
        A.film_id,
        A.title,
        A.release_year,
        A.rating
    FROM film A
        JOIN film_category B 
            ON A.film_id = B.film_id
        JOIN category C 
            ON B.category_id = C.category_id
            AND A.rating = 'PG'
            AND C.name = 'Comedy';
"""

pd.read_sql(query, con=conn)
# Out:
#       name  film_id                  title  release_year rating
# 0   Comedy       99    BRINGING HYSTERICAL          2006     PG
# 1   Comedy      188             CRAZY HOME          2006     PG
# 2   Comedy      265            DYING MAKER          2006     PG
# 3   Comedy      308          FERRIS MOTHER          2006     PG
# 4   Comedy      317  FIREBALL PHILADELPHIA          2006     PG
# 5   Comedy      404          HATE HANDICAP          2006     PG
# 6   Comedy      410         HEAVEN FREEDOM          2006     PG
# 7   Comedy      443       HURRICANE AFFAIR          2006     PG
# 8   Comedy      524             LION UNCUT          2006     PG
# 9   Comedy      555        MALLRATS UNITED          2006     PG
# 10  Comedy      660            PARTY KNOCK          2006     PG
# 11  Comedy      680        PINOCCHIO SIMON          2006     PG
# 12  Comedy      814         SNATCH SLIPPER          2006     PG
# 13  Comedy      837            STAGE WORLD          2006     PG
# 14  Comedy      871         SWEDEN SHINING          2006     PG
# 15  Comedy      906           TRAMP OTHERS          2006     PG

# %%
# Display the total number of sales and revenue for each branch.
query = """
    SELECT
        A.store_id,
        B.address,
        COUNT(*) AS totalN,
        ROUND(SUM(D.amount), 2) AS totalSales
    FROM store A
        JOIN address B 
            ON A.address_id = B.address_id
        JOIN staff C 
            ON A.store_id = C.store_id
        JOIN payment D 
            ON C.staff_id = D.staff_id
    GROUP BY 1, 2
    ORDER BY 4 DESC;
"""

pd.read_sql(query, con=conn)
# Out:
#    store_id             address  totalN  totalSales
# 0         2  28 MySQL Boulevard    7990    33924.06
# 1         1   47 MySakila Drive    8054    33482.50

# %%
# Display the overall sales and revenue generated in 2005.
query = """
    SELECT
        A.store_id,
        address,
        DATE_FORMAT(payment_date, '%%Y%%m') AS monthId,
        COUNT(*) AS totalN,
        ROUND(SUM(D.amount), 2) AS totalSales
    FROM store A
        JOIN address B 
            ON A.address_id = B.address_id
        JOIN staff C 
            ON A.store_id = C.store_id
        JOIN payment D 
            ON C.staff_id = D.staff_id
    GROUP BY 1, 2, 3
    HAVING 
        monthId LIKE '2005%%'
    ORDER BY 1, 3;
"""

pd.read_sql(query, con=conn)
# Out:
#    store_id             address monthId  totalN  totalSales
# 0         1   47 MySakila Drive  200505     617     2621.83
# 1         1   47 MySakila Drive  200506    1163     4774.37
# 2         1   47 MySakila Drive  200507    3344    13998.56
# 3         1   47 MySakila Drive  200508    2835    11853.65
# 4         2  28 MySQL Boulevard  200505     539     2201.61
# 5         2  28 MySQL Boulevard  200506    1148     4855.52
# 6         2  28 MySQL Boulevard  200507    3365    14370.35
# 7         2  28 MySQL Boulevard  200508    2851    12216.49

# %%
# Display the list of names for customers who haven't returned their DVDs yet.
query = """
    SELECT 
        DISTINCT A.first_name,
        A.last_name,
        B.address,
        B.postal_code
    FROM customer A
        JOIN address B 
            ON A.address_id = B.address_id
        JOIN rental C 
            ON A.customer_id = C.customer_id
    WHERE 
        C.return_date IS NULL
    ORDER BY 1;
"""

pd.read_sql(query, con=conn)
# Out:
#     first_name last_name                           address postal_code
# 0       ADRIAN     CLARY                  1986 Sivas Place       95775
# 1       ALBERT    CROUSE               1641 Changhwa Place       37636
# 2      ALBERTO   HENNING       502 Mandi Bahauddin Parkway       15992
# 3       ALICIA     MILLS                 1963 Moscow Place       64863
# 4        ALLAN   CORNISH                 947 Trshavn Place         841
# ..         ...       ...                               ...         ...
# 154      WENDY  HARRISON          1107 Nakhon Sawan Avenue       75149
# 155     WILLIE    HOWELL  1244 Allappuzha (Alleppey) Place       20657
# 156     WILLIE   MARKHAM              1623 Kingstown Drive       91299
# 157    YOLANDA    WEAVER             605 Rio Claro Parkway       49348
# 158    ZACHARY      HITE            98 Pyongyang Boulevard       88749
#
# [159 rows x 4 columns]

# %%
# Display the list of DVDs available for rental at either store 1 or 2 only.
query = """
    SELECT 
        DISTINCT release_year,
        title,
        rating,
        store_id
    FROM film A
        JOIN inventory B 
            ON A.film_id = B.film_id
    WHERE 
        A.film_id IN (
            SELECT film_id
            FROM inventory
            GROUP BY 1
            HAVING COUNT(DISTINCT store_id) = 1
        )
    ORDER BY title;
"""

pd.read_sql(query, con=conn)
# Out:
#      release_year             title rating  store_id
# 0            2006    ACE GOLDFINGER      G         2
# 1            2006  ADAPTATION HOLES  NC-17         2
# 2            2006       AFRICAN EGG      G         2
# 3            2006   AIRPORT POLLOCK      R         2
# 4            2006       ALI FOREVER     PG         2
# ..            ...               ...    ...       ...
# 390          2006        WRATH MILE  NC-17         2
# 391          2006     WYOMING STORM  PG-13         1
# 392          2006    YOUNG LANGUAGE      G         1
# 393          2006        YOUTH KICK  NC-17         1
# 394          2006      ZHIVAGO CORE  NC-17         2
#
# [395 rows x 4 columns]

# %%
# Display the list of the top 10 best-selling movies.
query = """
    SELECT
        film.title,
        category.name,
        SUM(amount) AS totalSales
    FROM film
        JOIN inventory      USING(film_id)
        JOIN rental         USING(inventory_id)
        JOIN payment        USING(rental_id)
        JOIN film_category  USING(film_id)
        JOIN category       USING(category_id)
    GROUP BY 1, 2
    ORDER BY 3 DESC
    LIMIT 10;
"""

pd.read_sql(query, con=conn)
# Out:
#                title         name  totalSales
# 0   TELEGRAPH VOYAGE        Music      231.73
# 1          WIFE TURN  Documentary      223.69
# 2          ZORRO ARK       Comedy      214.69
# 3  GOODFELLAS SALUTE       Sci-Fi      209.69
# 4     SATURDAY LAMBS       Sports      204.72
# 5        TITANS JERK       Sci-Fi      201.71
# 6       TORQUE BOUND        Drama      198.72
# 7        HARRY IDAHO        Drama      195.70
# 8     INNOCENT USUAL      Foreign      191.74
# 9      HUSTLER PARTY       Comedy      190.78

# %%
# Display the list of the 10 actors with the lowest income from rental sales.
query = """
    SELECT
        CONCAT(actor.first_name, ' ', actor.last_name) AS full_name,
        ROUND(SUM(amount), 2) AS totalSales
    FROM actor
        JOIN film_actor     USING(actor_id)
        JOIN film           USING(film_id)
        JOIN inventory      USING(film_id)
        JOIN rental         USING(inventory_id)
        JOIN payment        USING(rental_id)
    GROUP BY 1
    ORDER BY 2
    LIMIT 10;
"""

pd.read_sql(query, con=conn)
# Out:
#           full_name  totalSales
# 0         EMILY DEE      883.85
# 1    SISSY SOBIESKI      902.65
# 2        ADAM GRANT      974.19
# 3         JUDY DEAN      976.47
# 4       SANDRA PECK     1040.12
# 5    JENNIFER DAVIS     1052.27
# 6   JULIA ZELLWEGER     1064.79
# 7     JULIA FAWCETT     1189.42
# 8  PENELOPE GUINESS     1230.94
# 9     RUSSELL CLOSE     1251.05

# %%
# Display the rental date/time range for each movie.
query = """
    SELECT
        rental_id,
        rental_date,
        return_date,
        DATEDIFF(return_date, rental_date) AS rent_days,
        TIMESTAMPDIFF(HOUR, rental_date, return_date) AS rent_hours
    FROM rental
    WHERE 
        return_date IS NOT NULL
    ORDER BY rent_days DESC, rent_hours DESC;
"""

pd.read_sql(query, con=conn)
# Out:
#        rental_id         rental_date         return_date  rent_days  \
# 0          12048 2005-08-17 20:49:24 2005-08-27 02:01:24         10
# 1          12091 2005-08-17 22:22:50 2005-08-27 03:55:50         10
# 2          12765 2005-08-18 23:21:50 2005-08-28 04:42:50         10
# 3          12774 2005-08-18 23:34:22 2005-08-28 05:00:22         10
# 4          14622 2005-08-21 18:25:59 2005-08-31 00:11:59         10
# ...          ...                 ...                 ...        ...
# 15856       5004 2005-07-09 01:20:50 2005-07-09 19:56:50          0
# 15857       5070 2005-07-09 04:58:26 2005-07-09 23:00:26          0
# 15858       5071 2005-07-09 05:00:39 2005-07-09 23:08:39          0
# 15859       5589 2005-07-10 04:22:58 2005-07-10 23:13:58          0
# 15860       5608 2005-07-10 05:08:26 2005-07-10 23:24:26          0
#
#        rent_hours
# 0             221
# 1             221
# 2             221
# 3             221
# 4             221
# ...           ...
# 15856          18
# 15857          18
# 15858          18
# 15859          18
# 15860          18
#
# [15861 rows x 5 columns]

# %%
# Display the total sales and running total for each month.
query = """
    WITH payment_amt AS (
        SELECT
            DATE_FORMAT(payment_date, '%%Y-%%m') AS payment_date,
            SUM(amount) AS amount
        FROM payment
        GROUP BY 1
    )

    SELECT
        payment_date,
        ROUND(amount, 2) AS amount,
        ROUND(SUM(amount) OVER(ORDER BY payment_date), 2) AS rollAmt
    FROM payment_amt;
"""

pd.read_sql(query, con=conn)
# Out:
#   payment_date    amount   rollAmt
# 0      2005-05   4823.44   4823.44
# 1      2005-06   9629.89  14453.33
# 2      2005-07  28368.91  42822.24
# 3      2005-08  24070.14  66892.38
# 4      2006-02    514.18  67406.56
